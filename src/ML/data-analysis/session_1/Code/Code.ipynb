# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4])
type(s)
# Out:
# pandas.Series

# %%
s1 = pd.Series([1,2,3,4],index = ['A','B','C','D'])
print(s1)
type(s1)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64
# pandas.Series

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,777,'xyz'],
        [5,888,'lmn']
        ]
df = pd.DataFrame(data, columns=["ID","Std_id","Dept"],index=["A","B","C","E","F"])
df
# Out:
#    ID  Std_id Dept
# A   1     444  abc
# B   2     555  def
# C   3     666  ghi
# E   4     777  xyz
# F   5     888  lmn

# %%
data2 ={"ID": [1,2,3,4,5],
        "Std_id":[444,555,666,777,888],
        "Dept":['abc','def','ghi','jkl','mno']
        }
df2 = pd.DataFrame(data2,index=["A","B","C","E","F"])
df2
# Out:
#    ID  Std_id Dept
# A   1     444  abc
# B   2     555  def
# C   3     666  ghi
# E   4     777  jkl
# F   5     888  mno

# %%
df2.index
# Out:
# Index(['A', 'B', 'C', 'E', 'F'], dtype='str')

# %%
display(df)
# Out:
#    ID  Std_id Dept
# A   1     444  abc
# B   2     555  def
# C   3     666  ghi
# E   4     777  xyz
# F   5     888  lmn

# %%
df.dtypes
# Out:
# ID        int64
# Std_id    int64
# Dept        str
# dtype: object

# %%
df['Dept'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['Dept'] = df['Dept'].astype('category')

# %%
df['Dept'].dtype
# Out:
# CategoricalDtype(categories=['abc', 'def', 'ghi', 'lmn', 'xyz'], ordered=False, categories_dtype=str)

# %%
df.describe(include="category")
# Out:
#        Dept
# count     5
# unique    5
# top     abc
# freq      1

# %%
df.columns
# Out:
# Index(['ID', 'Std_id', 'Dept'], dtype='str')

# %%
df['Std_id'].unique().sum()
# Out:
# 3330

# %%
df['Std_id'].max()
# Out:
# 888

# %%
df['Std_id'].min()
# Out:
# 444

# %%
df['Std_id'].idxmax()
# Out:
# 'F'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5 entries, A to F
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Std_id  5 non-null      int64
#  2   Dept    5 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 509.0+ bytes

# %%
df['Dept'].value_counts()
# Out:
# Dept
# abc    1
# def    1
# ghi    1
# lmn    1
# xyz    1
# Name: count, dtype: int64

# %%
df['ID'].sum()
# Out:
# 15

# %%
df['Std_id'].apply(lambda x: x*2)
# Out:
# A     888
# B    1110
# C    1332
# E    1554
# F    1776
# Name: Std_id, dtype: int64

# %%
df.iloc[0:2]
# Out:
#    ID  Std_id Dept
# A   1     444  abc
# B   2     555  def

# %%
df.iloc[:,0:2]
# Out:
#    ID  Std_id
# A   1     444
# B   2     555
# C   3     666
# E   4     777
# F   5     888

# %%
df.isnull().sum()
# Out:
# ID        0
# Std_id    0
# Dept      0
# dtype: int64

# %%
null = df.isnull().sum()
pd.DataFrame(null).T
# Out:
#    ID  Std_id  Dept
# 0   0       0     0
